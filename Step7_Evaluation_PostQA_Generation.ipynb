# %% [markdown]
# # Semantic Redundancy Detection Using FAISS + SBERT

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
import json
import re
from pathlib import Path
from tqdm import tqdm
import time

# Extract question from 'input' field
def extract_question(input_text):
    match = re.search(r"### Question:\n(?:question:\s*)?(.*)", input_text)
    return match.group(1).strip() if match else ""

# Load QA Dataset
qa_path = Path("/mnt/data/First_RUN_final_3gpp_qa_filtered.jsonl")
qa_data = [json.loads(line) for line in qa_path.open("r", encoding="utf-8")]
questions = [extract_question(q["input"]) for q in qa_data]

print(f"Loaded {len(questions)} questions...")

# Load SBERT Model on GPU for fast embedding
model = SentenceTransformer("all-MiniLM-L6-v2", device="cuda")

# Generate Embeddings
print("Encoding questions...")
embeddings = model.encode(questions, convert_to_numpy=True, show_progress_bar=True)

# Normalize for cosine similarity
faiss.normalize_L2(embeddings)

# Build FAISS CPU Index
print("Building FAISS CPU index...")
dim = embeddings.shape[1]
index = faiss.IndexFlatIP(dim)  # Inner Product for cosine similarity
index.add(embeddings)

# Chunked CPU-based Search to avoid RAM spikes
print("Running chunked FAISS search on CPU...")
batch_size = 20000
all_scores = []
all_indices = []

start = time.time()
for i in tqdm(range(0, len(embeddings), batch_size), desc="Searching..."):
    batch = embeddings[i:i + batch_size]
    D, I = index.search(batch, 2)  # Top-2 similarity
    all_scores.append(D)
    all_indices.append(I)
end = time.time()
print(f"Search completed in {end - start:.2f} seconds.")

# Merge Results
D = np.vstack(all_scores)
I = np.vstack(all_indices)

# Analyze Redundant Pairs
threshold = 0.95
redundant_pairs = []
for i in range(len(questions)):
    j = I[i][1]  # skip self-match
    score = D[i][1]
    if score > threshold:
        redundant_pairs.append((i, j, score))

# Summary Stats
print("\n=== Semantic Redundancy (FAISS CPU) ===")
print(f"Total QA pairs: {len(questions)}")
print(f"Highly similar (cosine > {threshold}): {len(redundant_pairs)}")
print(f"Redundancy rate: {len(redundant_pairs) / len(questions) * 100:.2f}%")

# Show Top 10 Redundant Question Pairs
print("\n=== Top 10 Most Similar Question Pairs ===")
top_pairs = sorted(redundant_pairs, key=lambda x: -x[2])[:10]
for i, j, score in top_pairs:
    print(f"[{score:.3f}] Q{i}: {questions[i]}\n        Q{j}: {questions[j]}\n")
# Out:
# Loaded 218347 questions...
# Encoding questions...
# Batches:   0%|          | 0/6824 [00:00<?, ?it/s]
# Building FAISS CPU index...
# Running chunked FAISS search on CPU...
# Searching...: 100%|██████████████████████████| 11/11 [07:07<00:00, 38.83s/it]
# Search completed in 427.10 seconds.
#
# === Semantic Redundancy (FAISS CPU) ===
# Total QA pairs: 218347
# Highly similar (cosine > 0.95): 108948
# Redundancy rate: 49.90%
#
# === Top 10 Most Similar Question Pairs ===
# [1.000] Q189687: What does the VLR support but does not support the Operator Determined Barring category?
#         Q95485: What does the VLR support but does not support the Operator Determined Barring category?
#
# [1.000] Q66668: What clause states that the message "Mess_Sync_Lost" is sent only at the first five occurrences of errors in Tandem Free Operation (TFO) Frames or loss of synchronisation?
#         Q66668: What clause states that the message "Mess_Sync_Lost" is sent only at the first five occurrences of errors in Tandem Free Operation (TFO) Frames or loss of synchronisation?
#
# [1.000] Q95485: What does the VLR support but does not support the Operator Determined Barring category?
#         Q95485: What does the VLR support but does not support the Operator Determined Barring category?
#
# [1.000] Q118696: What clause states that the message "Mess_Sync_Lost" is sent only at the first five occurrences of errors in Tandem Free Operation (TFO) Frames or loss of synchronisation?
#         Q66668: What clause states that the message "Mess_Sync_Lost" is sent only at the first five occurrences of errors in Tandem Free Operation (TFO) Frames or loss of synchronisation?
#
# [1.000] Q141567: What is the test environment for a PUSCH receiver?
#         Q141567: What is the test environment for a PUSCH receiver?
#
# [1.000] Q185304: What is the test environment for a PUSCH receiver?
#         Q141567: What is the test environment for a PUSCH receiver?
#
# [1.000] Q247: What type of code group is stored in the Managed Elements (ME)?
#         Q44151: What type of code group is stored in the Managed Elements (ME)?
#
# [1.000] Q10954: What should the Mission Critical Push To Talk (MCPTT) client include in the Contact header field of the Session Initiation Protocol (SIP) REGISTER request without service authorisation?
#         Q10954: What should the Mission Critical Push To Talk (MCPTT) client include in the Contact header field of the Session Initiation Protocol (SIP) REGISTER request without service authorisation?
#
# [1.000] Q15803: What two components are elaborated below?
#         Q15803: What two components are elaborated below?
#
# [1.000] Q17485: What is a symbol modulator?
#         Q17485: What is a symbol modulator?

# %% [markdown]
# # Model-Based QA Answer Accuracy (EM & F1)

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForQuestionAnswering
from tqdm import tqdm
import json
from pathlib import Path
import numpy as np
import re

# Load fine-tuned telecom QA model
model_path = "/home/ec2-user/qa_roberta_telecom"
qa_pipeline = pipeline(
    "question-answering",
    model=AutoModelForQuestionAnswering.from_pretrained(model_path),
    tokenizer=AutoTokenizer.from_pretrained(model_path),
    device=0
)

# Load data
qa_path = Path("/mnt/data/First_RUN_final_3gpp_qa_filtered.jsonl")
qa_data = [json.loads(line) for line in qa_path.open("r", encoding="utf-8")]

# Prepare inputs
inputs = []
gold_answers = []
for item in qa_data:
    input_text = item.get("input", "")
    match = re.search(r"### Context:\n(.*?)\n\n### Question:\n(?:question:\s*)?(.*)", input_text, re.DOTALL)
    if match:
        context = match.group(1).strip()
        question = match.group(2).strip()
    else:
        continue  # skip malformed entries
    gold = item["output"].strip()
    if context and question and gold:
        inputs.append({"context": context, "question": question})
        gold_answers.append(gold)

# Chunked QA inference
print("Running chunked QA inference...")
predictions = []
batch_size = 512  # adjust to 256/128 if OOM
for i in tqdm(range(0, len(inputs), batch_size)):
    batch = inputs[i:i + batch_size]
    preds = qa_pipeline(batch)
    predictions.extend(preds)

# Evaluation
def compute_f1(pred, truth):
    pred_tokens = pred.lower().split()
    truth_tokens = truth.lower().split()
    common = set(pred_tokens) & set(truth_tokens)
    if not common:
        return 0.0
    precision = len(common) / len(pred_tokens)
    recall = len(common) / len(truth_tokens)
    return 2 * precision * recall / (precision + recall)

em_scores = []
f1_scores = []
for pred, gold in zip(predictions, gold_answers):
    p = pred["answer"].strip()
    g = gold.strip()
    em_scores.append(int(p.lower() == g.lower()))
    f1_scores.append(compute_f1(p, g))

# Final report
print("\n=== Batch QA Evaluation Results ===")
print(f"Total evaluated: {len(em_scores)}")
print(f"Exact Match (EM): {np.mean(em_scores):.4f}")
print(f"F1 Score:          {np.mean(f1_scores):.4f}")
# Out:
# Device set to use cuda:0
# Running chunked QA inference...
#   0%|                                                | 0/427 [00:00<?, ?it/s]/home/ec2-user/.local/lib/python3.9/site-packages/transformers/pipelines/question_answering.py:390: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
#   0%|                                        | 1/427 [00:04<29:15,  4.12s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2407ccfd0> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
#   0%|▏                                       | 2/427 [00:08<28:52,  4.08s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb240a894f0> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb240a894f0> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
#   2%|▉                                      | 10/427 [00:41<28:40,  4.13s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   3%|█▏                                     | 13/427 [00:53<28:26,  4.12s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c590d0> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
#   4%|█▍                                     | 16/427 [01:05<28:09,  4.11s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 515 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 516 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 517 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 518 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 519 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 520 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 521 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 522 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 523 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 524 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 525 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 526 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 527 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 528 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 529 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 530 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 531 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 532 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 533 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 534 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 535 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 536 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 537 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 538 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 539 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 540 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 541 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 542 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 543 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 544 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 545 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 546 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 547 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 548 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 549 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 550 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 551 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 552 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 553 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 554 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 555 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 556 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 557 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 558 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 559 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 560 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 561 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 562 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 563 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 564 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 565 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 566 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 567 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 568 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 569 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 570 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 571 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 572 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 573 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 574 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 575 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 576 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 577 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 578 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 579 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 580 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 581 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 582 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 583 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 584 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 585 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 586 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 587 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 588 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 589 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 590 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 591 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 592 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 593 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 594 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 595 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 596 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 597 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 598 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 599 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 600 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 601 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 602 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 603 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 604 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 605 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 606 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 607 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 608 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 609 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 610 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 611 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 612 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 613 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 614 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 615 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 616 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 617 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 618 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 619 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 620 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 621 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 622 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 623 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 624 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 625 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 626 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 627 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 628 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 629 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 630 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 631 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 632 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 633 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 634 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 635 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 636 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 637 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 638 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 639 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 640 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 641 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 642 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 643 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 644 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 645 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 646 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 647 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 648 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 649 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 650 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 651 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 652 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27394afd0> was reported to be 512(when accessing len(dataloader)), but 653 samples have been fetched.
#   warnings.warn(warn_msg)
# ...
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 515 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 516 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 517 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 518 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 519 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 520 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 521 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 522 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 523 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 524 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 525 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 526 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 527 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 528 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 529 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 530 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b2b943a0> was reported to be 512(when accessing len(dataloader)), but 531 samples have been fetched.
#   warnings.warn(warn_msg)
#  98%|█████████████████████████████████████▎| 419/427 [30:57<00:35,  4.42s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 515 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 516 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 517 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 518 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 519 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 520 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb3a81b4d30> was reported to be 512(when accessing len(dataloader)), but 521 samples have been fetched.
#   warnings.warn(warn_msg)
#  98%|█████████████████████████████████████▍| 420/427 [31:02<00:30,  4.42s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b29cfa90> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1b29cfa90> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
#  99%|█████████████████████████████████████▍| 421/427 [31:06<00:26,  4.40s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 515 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 516 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 517 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 518 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 519 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 520 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 521 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c453a0> was reported to be 512(when accessing len(dataloader)), but 522 samples have been fetched.
#   warnings.warn(warn_msg)
#  99%|█████████████████████████████████████▌| 422/427 [31:10<00:22,  4.41s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27380a4c0> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb27380a4c0> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
#  99%|█████████████████████████████████████▋| 423/427 [31:15<00:17,  4.38s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb1ade63280> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
#  99%|█████████████████████████████████████▋| 424/427 [31:19<00:13,  4.34s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c6e970> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb2a0c6e970> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
# 100%|█████████████████████████████████████▊| 425/427 [31:23<00:08,  4.35s/it]/home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb26a862e50> was reported to be 512(when accessing len(dataloader)), but 513 samples have been fetched.
#   warnings.warn(warn_msg)
# /home/ec2-user/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:718: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x7fb26a862e50> was reported to be 512(when accessing len(dataloader)), but 514 samples have been fetched.
#   warnings.warn(warn_msg)
# 100%|██████████████████████████████████████| 427/427 [31:30<00:00,  4.43s/it]
# === Batch QA Evaluation Results ===
# Total evaluated: 218347
# Exact Match (EM): 0.9543
# F1 Score:          0.9651
